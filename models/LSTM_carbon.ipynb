# %%
# !pip install --upgrade s3fs

# %%
import pandas as pd
import numpy as np

# S3 경로
train_path = 's3://smwu-project-datasets/traing-dataset/rtu_data_full.csv'
val_path = 's3://smwu-project-datasets/may-dataset/rtu_ground_truth_may.csv'

# %%
raw_df = pd.read_csv(train_path)
val_df = pd.read_csv(val_path)

# %%
cols_to_keep = [
    'timestamp',
    'module(equipment)',
    'accumActiveEnergy',  # delta_kWh 계산용
    'activePower'         # 예측 피처
]
train_df = raw_df[cols_to_keep].copy()

# %%
# 전처리
def preprocess_data(df):
    # timestamp → datetime 변환
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.sort_values('timestamp', inplace=True)
    df.set_index('timestamp', inplace=True) # 인덱스로 설정

    # 시간 관련 파생 변수 생성
    df['date'] = df.index.date
    df['hour'] = df.index.hour
    df['weekday'] = df.index.weekday
    df['is_weekend'] = df['weekday'].isin([5, 6])  # 주말 여부
    df['is_night'] = df['hour'].between(0, 6)      # 야간 여부

    # 수치형 컬럼에 대한 선형 보간
    numeric_cols = df.select_dtypes(include='number').columns
    df[numeric_cols] = df[numeric_cols].interpolate(method='linear', limit_direction='both')

    # activePower 기반 delta_kWh 계산 (5초 주기 기준)
    df['delta_kWh'] = df['activePower'] * (5 / 3600)

    # 요금 및 탄소 배출량 계산
    df['electricity_cost'] = df['delta_kWh'] * 180
    df['carbon_emission'] = df['delta_kWh'] * 0.424

    return df

# %%
train_df = preprocess_data(train_df)

# %%
# 1시간 단위 집계
hourly_train = train_df.resample('1H').agg({
    'activePower': 'sum',
    'delta_kWh': 'sum',
}).dropna()

# 추가 피처 생성
hourly_train['hour'] = hourly_train.index.hour
hourly_train['weekday'] = hourly_train.index.weekday
hourly_train['hourly_pow'] = hourly_train['activePower'] * (5 / 3600)
hourly_train['carbon_estimated'] = hourly_train['delta_kWh'] * 0.424
hourly_train['bill_estimated'] = hourly_train['delta_kWh'] * 180

# 확인
print("NaN 비율:", hourly_train['carbon_estimated'].isna().mean() * 100)
print(hourly_train[['carbon_estimated']].head())
print(hourly_train[['carbon_estimated']].tail())
print(hourly_train[['hourly_pow']].head())
# Out:
# NaN 비율: 0.0
#                      carbon_estimated
# timestamp
# 2024-12-01 08:00:00      16630.139318
# 2024-12-01 09:00:00      16633.255630
# 2024-12-01 10:00:00      16508.020458
# 2024-12-01 11:00:00      16564.361154
# 2024-12-01 12:00:00      16599.239947
#                      carbon_estimated
# timestamp
# 2025-04-30 03:00:00      16586.810470
# 2025-04-30 04:00:00      16638.036589
# 2025-04-30 05:00:00      16494.283176
# 2025-04-30 06:00:00      16656.213287
# 2025-04-30 07:00:00         22.982737
#                        hourly_pow
# timestamp
# 2024-12-01 08:00:00  39222.026694
# 2024-12-01 09:00:00  39229.376486
# 2024-12-01 10:00:00  38934.010514
# 2024-12-01 11:00:00  39066.889514
# 2024-12-01 12:00:00  39149.150819

# %%
# !pip install tensorflow

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import numpy as np
import random
import tensorflow as tf

np.random.seed(10)
random.seed(10)
tf.random.set_seed(10)

ts = hourly_train['carbon_estimated'].dropna().values.reshape(-1, 1)  # (n, 1) 형태로
# Out:
# 2025-05-29 19:33:30.182561: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-29 19:33:30.198254: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748547210.217122   25331 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748547210.222696   25331 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# 정규화 - RobustScaler 사용
scaler = RobustScaler()
ts_scaled = scaler.fit_transform(ts)

# %%
# 시퀀스 생성
def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(len(data) - seq_len):
        X.append(data[i:i+seq_len])
        y.append(data[i+seq_len])
    return np.array(X), np.array(y)

SEQ_LEN = 24  # 과거 24시간 사용
X, y = create_sequences(ts_scaled, SEQ_LEN)

# %%
# 학습
split_idx = len(X) - len(val_df)
X_train, X_val = X[:split_idx], X[split_idx:]
y_train, y_val = y[:split_idx], y[split_idx:]

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(SEQ_LEN, 1)),
    Dropout(0.1), 
    LSTM(32),
    Dense(16, activation='relu'),  # 중간 표현력 강화
    Dense(1)
])

model.compile(optimizer='adam', loss='mae')  # MAE or Huber

# EarlyStopping 콜백 설정
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# 학습
model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,                 # 충분히 크게 두고
    batch_size=32,
    #callbacks=[early_stop],    # EarlyStopping 적용
    verbose=2
)
# Out:
# Epoch 1/100
# W0000 00:00:1748547212.325770   25331 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 96/96 - 4s - 43ms/step - loss: 0.7012 - val_loss: 1.2339
# Epoch 2/100
# 96/96 - 1s - 13ms/step - loss: 0.7008 - val_loss: 1.2340
# Epoch 3/100
# 96/96 - 1s - 13ms/step - loss: 0.7005 - val_loss: 1.2336
# Epoch 4/100
# 96/96 - 1s - 13ms/step - loss: 0.7010 - val_loss: 1.2340
# Epoch 5/100
# ...

# %%
# # ✅ 모델을 .h5로 저장
# model.save("carbon_model_v1.h5")  # 이 줄이 꼭 있어야 아래 load_model이 가능해요!

# # ✅ SavedModel 포맷으로 변환
# model = tf.keras.models.load_model("carbon_model_v1.h5", compile=False)
# model.save("export/1")  # 자동서빙용 포맷

# %%
# 예측
y_pred = model.predict(X_val)

# 역정규화
carbon_pred_lstm = scaler.inverse_transform(y_pred)
carbon_actual = scaler.inverse_transform(y_val)

# 날짜 인덱스 붙이기
lstm_index = pd.date_range(start="2025-05-10 00:00:00", periods=len(carbon_pred_lstm), freq='H')
carbon_pred_lstm_series = pd.Series(carbon_pred_lstm.flatten(), index=lstm_index)

# 평가
mae = mean_absolute_error(carbon_actual, carbon_pred_lstm)
mape = mean_absolute_percentage_error(carbon_actual, carbon_pred_lstm) * 100
r2 = r2_score(carbon_actual, carbon_pred_lstm)

print(f"LSTM 평가 결과:")
print(f"MAE: {mae:.2f} g")
print(f"MAPE: {mape:.2f} %")
print(f"R²: {r2:.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# LSTM 평가 결과:
# MAE: 69.79 g
# MAPE: 142.79 %
# R²: 0.0001

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(lstm_index, carbon_actual, label="Actual")
plt.plot(lstm_index, carbon_pred_lstm, label="Predicted (LSTM)")
plt.title("LSTM Carbon Emission Prediction")
plt.ylabel("Carbon Emission (g)")
plt.xlabel("Time")
plt.legend()
plt.grid(True)
plt.ylim([16450, 16700])
plt.tight_layout()
plt.show()

# %%
print("평균값:", carbon_actual.mean())
print("MAE:", mae)
print("상대 오차(%):", mae / carbon_actual.mean() * 100)
# Out:
# 평균값: 16559.521654423323
# MAE: 69.78855656952699
# 상대 오차(%): 0.4214406552672692

# %%
print("실제 탄소 배출량 총합: ", carbon_actual.sum())
print("예측 탄소 배출량 총합: ", carbon_pred_lstm.sum())

# 절대 오차
abs_error = abs(carbon_actual.sum() - carbon_pred_lstm.sum())

# 상대 오차 (%)
relative_error_percent = abs_error / carbon_actual.sum() * 100

print(f"절대 오차: {abs_error:.2f} g")
print(f"상대 오차: {relative_error_percent:.4f} %")
# Out:
# 실제 탄소 배출량 총합:  8362558.435483778
# 예측 탄소 배출량 총합:  8378993.0
# 절대 오차: 16434.56 g
# 상대 오차: 0.1965 %

# %%
top_idx = ts.flatten().argsort()[-10:]
top_values = ts.flatten()[top_idx]
bottom_idx = ts.flatten().argsort()[:10]
bottom_values = ts.flatten()[bottom_idx]

print("상위 10개 큰 값:")
print(top_values)
print("하위 10개 작은 값:")
print(bottom_values)
# Out:
# 상위 10개 큰 값:
# [16706.16871944 16707.87676811 16710.46223178 16712.1031
#  16717.99197711 16721.17207133 16721.59713133 16723.74892544
#  16723.90124744 33234.283562  ]
# 하위 10개 작은 값:
# [   22.98273744 16444.20288111 16458.28937422 16467.13007456
#  16468.59255656 16473.17343489 16474.80261367 16475.064257
#  16475.17535678 16477.47215889]

# %%
# model.save("carbon_model_v1.h5")

# %%
# import joblib
# joblib.dump(scaler, 'carbon_scaler.pkl')

# %%
# 안전하게 재설정
del X_train, y_train, X_val, y_val, scaler, model
